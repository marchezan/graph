# %%
import matplotlib.pyplot as plt

# %%
x = [1,3,5,7,9]
y= [0.86,0.98,0.97,0.96,0.97]

# %%
#plt.title('Faturamento no primeiro semestre de 2017')
plt.xlabel('k_values')
plt.ylabel('accuracy_values')
plt.grid()
plt.xlim(0, 10)
plt.xticks(range(1,10,2))
plt.plot (x,y)
plt.show()

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y= [0.92, 0.94, 0.95, 0.97, 0.99, 0.98, 0.99, 0.98, 0.98]

# %%
plt.xlabel('num_hidden_neurons')
plt.ylabel('accuracy_values')
plt.grid()
plt.plot (x,y)
plt.show()
